# %% [markdown]
# # **Exploratory Data Analysis using Visualization**
#
#
#
# Q1.
#     Countplot of Passengers by Gender
#     sns.countplot(x='Sex', data=df)
#
#     plt.title("Number of Passengers by Gender")
#
#     plt.xlabel("Gender")
#
#     plt.ylabel("Count")
#
#     plt.show()
#     Interpretation
#     The chart shows the number of male and female passengers.
#     Usually, male passengers are higher in number than female passengers.
#
#
# Q2.
#     Bar Chart of Passenger Class
#     df['Pclass'].value_counts().plot(
#     kind='bar',
#     color=['red', 'blue', 'green']
# )
#
#     plt.title("Passenger Count by Class")
#
#     plt.xlabel("Passenger Class")
#
#     plt.ylabel("Count")
#
#     plt.show()
#     Interpretation
#     Most passengers belonged to 3rd class.
#     1st class had fewer passengers compared to 3rd class.
#
#
# Q3.
#     Histogram of Passenger Age
#     plt.hist(df['Age'], bins=20)
#
#     plt.title("Age Distribution of Passengers")
#
#     plt.xlabel("Age")
#
#     plt.ylabel("Frequency")
#
#     plt.show()
#     Interpretation
#     Most passengers were between 20–40 years old.
#     Few elderly passengers were present.
#
#
# Q4.
#     Boxplot for Fare Column
#     sns.boxplot(y='Fare', data=df)
#
#     plt.title("Boxplot of Fare")
#
#     plt.show()
#     Interpretation
#     Several outliers are visible.
#     Some passengers paid extremely high ticket fares.
#
#
# Q5
#
#     (a). Scatterplot: Age vs Fare
#     sns.scatterplot(x='Age', y='Fare', data=df)
#
#     plt.title("Age vs Fare")
#
#     plt.xlabel("Age")
#
#     plt.ylabel("Fare")
#
#     plt.show()
#     Interpretation
#     No strong linear relationship exists between age and fare.
#     Higher fares are spread across multiple age groups.
#
#
# Q5
#
#     (b). Scatterplot: Family Size vs Fare
#     Create Family Size Column
#     df['FamilySize'] = df['SibSp'] + df['Parch']
#     Scatterplot
#     sns.scatterplot(x='FamilySize', y='Fare', data=df)
#
#     plt.title("Family Size vs Fare")
#
#     plt.xlabel("Family Size")
#
#     plt.ylabel("Fare")
#
#     plt.show()
#     Interpretation
#     Families with larger size sometimes paid higher fares.
#     Small families were more common.
#
#
# Q6.
#     Countplot of Survival by Gender
#     sns.countplot(x='Survived', hue='Sex', data=df)
#
#     plt.title("Survival Count by Gender")
#
#     plt.xlabel("Survived")
#
#     plt.ylabel("Count")
#
#     plt.show()
#     Interpretation
#     Female passengers had higher survival rates.
#     Many male passengers did not survive.
#
#
# Q7.
#     Bar Chart of Survival by Passenger Class
#     survival_class = df.groupby('Pclass')['Survived'].mean()
#
#     survival_class.plot(kind='bar', color=['gold', 'silver', 'brown'])
#
#     plt.title("Survival Rate by Passenger Class")
#
#     plt.xlabel("Passenger Class")
#
#     plt.ylabel("Survival Rate")
#
#     plt.show()
#     Interpretation
#     1st class passengers had the highest survival rate.
#     3rd class passengers had the lowest survival rate.
#
#
# Q8.
#
#     Correlation Heatmap
#     plt.figure(figsize=(10,6))
#
#     sns.heatmap(df.corr(numeric_only=True),
#             annot=True,
#             cmap='coolwarm')
#
#     plt.title("Correlation Heatmap")
#
#     plt.show()
#     Interpretation
#     Fare and Pclass show correlation.
#     Survival is positively related to Fare.
#     Survival is negatively related to Pclass number.
#
#
# Q9.
#
#     Passenger Class with Highest Average Fare
#     avg_fare = df.groupby('Pclass')['Fare'].mean()
#
#     print(avg_fare)
#     Interpretation
#     1st Class passengers paid the highest average fare.
#     3rd Class passengers paid the lowest average fare.
#
#
# Q10.
#
#     Final Insights from Dataset
#     Insight 1
#
#     Female passengers had significantly higher survival rates than males.
#
#     Insight 2
#
#     1st class passengers were more likely to survive.
#
#     Insight 3
#
#     Most passengers belonged to 3rd class.
#
#     Insight 4
#
#     The dataset contains fare outliers, indicating luxury ticket prices.
#
#     Insight 5
#
#     Most passengers were young adults between 20–40 years old.
#
#     Complete Code Together
#     import pandas as pd
#     import numpy as np
#
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#
# # Load dataset
# df = pd.read_csv("Titanic_Dataset.csv")
#
# # Basic exploration
# print(df.info())
# print(df.describe())
#
# # Handle missing values
# df['Age'].fillna(df['Age'].median(), inplace=True)
# df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
#
# # Q1
# sns.countplot(x='Sex', data=df)
# plt.title("Passengers by Gender")
# plt.show()
#
# # Q2
# df['Pclass'].value_counts().plot(kind='bar')
# plt.title("Passenger Class Distribution")
# plt.show()
#
# # Q3
# plt.hist(df['Age'], bins=20)
# plt.title("Age Distribution")
# plt.show()
#
# # Q4
# sns.boxplot(y='Fare', data=df)
# plt.title("Fare Boxplot")
# plt.show()
#
# # Q5(a)
# sns.scatterplot(x='Age', y='Fare', data=df)
# plt.title("Age vs Fare")
# plt.show()
#
# # Q5(b)
# df['FamilySize'] = df['SibSp'] + df['Parch']
#
# sns.scatterplot(x='FamilySize', y='Fare', data=df)
# plt.title("Family Size vs Fare")
# plt.show()
#
# # Q6
# sns.countplot(x='Survived', hue='Sex', data=df)
# plt.title("Survival by Gender")
# plt.show()
#
# # Q7
# df.groupby('Pclass')['Survived'].mean().plot(kind='bar')
# plt.title("Survival by Passenger Class")
# plt.show()
#
# # Q8
# plt.figure(figsize=(10,6))
# sns.heatmap(df.corr(numeric_only=True),
#             annot=True,
#             cmap='coolwarm')
# plt.show()
#
# # Q9
# print(df.groupby('Pclass')['Fare'].mean())
